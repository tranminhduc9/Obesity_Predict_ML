# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import pandas as pd
import numpy as np
import gdown
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
link="https://drive.google.com/drive/folders/1s2Ed1gkl-m6Dkn2CUp0xLxGUxLnbCa-U?dmr=1&ec=wgc-drive-globalnav-goto"
gdown.download_folder(link, output="/content/sample_data", quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Processing file 1ss49tQXEitL0zcXfQ0M4_ZCvbuw31jK2 obesity_data_cleaned.csv
# Processing file 158lb4W_q-OeN8_eldIDXXmz3bHtKTQDB obesity_data.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1ss49tQXEitL0zcXfQ0M4_ZCvbuw31jK2
# To: /content/sample_data/obesity_data_cleaned.csv
# 100%|██████████| 1.47M/1.47M [00:00<00:00, 46.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=158lb4W_q-OeN8_eldIDXXmz3bHtKTQDB
# To: /content/sample_data/obesity_data.csv
# 100%|██████████| 2.73M/2.73M [00:00<00:00, 43.0MB/s]
# Download completed
# ['/content/sample_data/obesity_data_cleaned.csv',
#  '/content/sample_data/obesity_data.csv']

# %%
df= pd.read_csv('/content/sample_data/obesity_data.csv')
df_cleaned = pd.read_csv('/content/sample_data/obesity_data_cleaned.csv')

# %%
df.head(3)
# Out:
#    id  Gender        Age    Height     Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998  81.669950                            yes
# 1   1  Female  18.000000  1.560000  57.000000                            yes
# 2   2  Female  18.000000  1.711460  50.165754                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight

# %%
hidden_layer_configs = [
    (64,),
    (128, 64),
    (128, 64, 32)
]

test_sizes = [
    0.2,
    0.3,
    0.4
]

# %%
X = df_cleaned.drop('NObeyesdad', axis=1)
y = df_cleaned['NObeyesdad']

# %%
lda = LDA(n_components=4)

# %%
continuous_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

lda_results = {}

for test_size in test_sizes:
    print(f"\n Test_size: {test_size*100:.0f}/{100 - test_size*100:.0f}----------------------------")
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=36, stratify=y
    )

    X_train_continuous = X_train[continuous_cols]
    X_test_continuous = X_test[continuous_cols]

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_continuous)
    X_test_scaled = scaler.transform(X_test_continuous)

    X_train_lda = lda.fit_transform(X_train_scaled, y_train)
    X_test_lda = lda.transform(X_test_scaled)

    lda_results[test_size] = {}

    for config in hidden_layer_configs:
        print(f"\n hidden_layer_sizes: {config}")
        mlp = MLPClassifier(
            hidden_layer_sizes=config,
            activation='relu',

            solver='sgd',
            learning_rate='constant',
            learning_rate_init=2e-4,

            momentum=0.0,
            nesterovs_momentum=False,

            alpha=0.0,
            shuffle=True,
            random_state=42,
            max_iter=1000,
            batch_size=32,

            early_stopping=False,
            validation_fraction=0.1,
            n_iter_no_change=20,

            tol=1e-4,
            verbose=False,
            warm_start=False,
        )

        mlp.fit(X_train_lda, y_train)

        plt.figure(figsize=(6,4))
        plt.plot(mlp.loss_curve_, marker='.')
        plt.title(f"Loss Curve for hidden_layer_sizes={config}, test_size={test_size}")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.grid(True)
        plt.show()

        y_pred = mlp.predict(X_test_lda)

        accuracy = accuracy_score(y_test, y_pred)
        report = classification_report(y_test, y_pred)
        cm = confusion_matrix(y_test, y_pred)
        n_epochs = mlp.n_iter_

        lda_results[test_size][config] = {
            'accuracy': accuracy,
            'classification_report': report,
            'confusion_matrix': cm,
            'loss_curve': mlp.loss_curve_,
            'n_epochs': n_epochs
        }

        print(f"    Accuracy: {accuracy:.4f}")
        print(f"    Number of epochs: {n_epochs}")
        print(f"    Classification Report:\n{report}")
# Out:
#  Test_size: 20/80----------------------------
#
#  hidden_layer_sizes: (64,)
#     Accuracy: 0.8223
#     Number of epochs: 621
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89       505
#            1       0.82      0.76      0.79       617
#            2       0.81      0.76      0.78       582
#            3       0.91      0.92      0.92       650
#            4       0.97      0.99      0.98       809
#            5       0.63      0.65      0.64       485
#            6       0.64      0.62      0.63       504
#
#     accuracy                           0.82      4152
#    macro avg       0.80      0.81      0.80      4152
# weighted avg       0.82      0.82      0.82      4152
#
#
#  hidden_layer_sizes: (128, 64)
#     Accuracy: 0.8285
#     Number of epochs: 488
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90       505
#            1       0.83      0.77      0.80       617
#            2       0.81      0.76      0.78       582
#            3       0.92      0.93      0.92       650
#            4       0.98      0.99      0.98       809
#            5       0.63      0.65      0.64       485
#            6       0.64      0.65      0.65       504
#
#     accuracy                           0.83      4152
#    macro avg       0.81      0.81      0.81      4152
# weighted avg       0.83      0.83      0.83      4152
#
#
#  hidden_layer_sizes: (128, 64, 32)
#     Accuracy: 0.8297
#     Number of epochs: 565
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90       505
#            1       0.84      0.77      0.80       617
#            2       0.81      0.77      0.79       582
#            3       0.91      0.93      0.92       650
#            4       0.98      0.98      0.98       809
#            5       0.63      0.63      0.63       485
#            6       0.65      0.66      0.66       504
#
#     accuracy                           0.83      4152
#    macro avg       0.81      0.81      0.81      4152
# weighted avg       0.83      0.83      0.83      4152
#
#
#  Test_size: 30/70----------------------------
#
#  hidden_layer_sizes: (64,)
#     Accuracy: 0.8224
#     Number of epochs: 676
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       757
#            1       0.82      0.76      0.79       925
#            2       0.80      0.77      0.79       873
#            3       0.92      0.92      0.92       974
#            4       0.97      0.98      0.98      1214
#            5       0.63      0.64      0.63       728
#            6       0.65      0.64      0.64       757
#
#     accuracy                           0.82      6228
#    macro avg       0.80      0.81      0.80      6228
# weighted avg       0.82      0.82      0.82      6228
#
#
#  hidden_layer_sizes: (128, 64)
#     Accuracy: 0.8312
#     Number of epochs: 495
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       757
#            1       0.84      0.77      0.80       925
#            2       0.80      0.78      0.79       873
#            3       0.92      0.93      0.92       974
#            4       0.98      0.98      0.98      1214
#            5       0.64      0.65      0.65       728
#            6       0.65      0.65      0.65       757
#
#     accuracy                           0.83      6228
#    macro avg       0.81      0.82      0.81      6228
# weighted avg       0.83      0.83      0.83      6228
#
#
#  hidden_layer_sizes: (128, 64, 32)
#     Accuracy: 0.8343
#     Number of epochs: 592
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90       757
#            1       0.84      0.77      0.81       925
#            2       0.80      0.79      0.80       873
#            3       0.92      0.93      0.93       974
#            4       0.98      0.98      0.98      1214
#            5       0.65      0.64      0.65       728
#            6       0.66      0.68      0.66       757
#
#     accuracy                           0.83      6228
#    macro avg       0.82      0.82      0.82      6228
# weighted avg       0.83      0.83      0.83      6228
#
#
#  Test_size: 40/60----------------------------
#
#  hidden_layer_sizes: (64,)
#     Accuracy: 0.8218
#     Number of epochs: 716
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88      1009
#            1       0.82      0.76      0.79      1233
#            2       0.79      0.78      0.79      1164
#            3       0.92      0.92      0.92      1299
#            4       0.97      0.98      0.97      1619
#            5       0.64      0.64      0.64       971
#            6       0.65      0.62      0.64      1009
#
#     accuracy                           0.82      8304
#    macro avg       0.80      0.81      0.80      8304
# weighted avg       0.82      0.82      0.82      8304
#
#
#  hidden_layer_sizes: (128, 64)
#     Accuracy: 0.8318
#     Number of epochs: 573
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      1009
#            1       0.83      0.77      0.80      1233
#            2       0.80      0.79      0.79      1164
#            3       0.92      0.93      0.92      1299
#            4       0.98      0.98      0.98      1619
#            5       0.65      0.65      0.65       971
#            6       0.66      0.65      0.65      1009
#
#     accuracy                           0.83      8304
#    macro avg       0.81      0.82      0.81      8304
# weighted avg       0.83      0.83      0.83      8304
#
#
#  hidden_layer_sizes: (128, 64, 32)
#     Accuracy: 0.8377
#     Number of epochs: 754
#     Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1009
#            1       0.84      0.78      0.81      1233
#            2       0.80      0.80      0.80      1164
#            3       0.93      0.94      0.93      1299
#            4       0.99      0.99      0.99      1619
#            5       0.66      0.65      0.65       971
#            6       0.66      0.67      0.67      1009
#
#     accuracy                           0.84      8304
#    macro avg       0.82      0.82      0.82      8304
# weighted avg       0.84      0.84      0.84      8304
